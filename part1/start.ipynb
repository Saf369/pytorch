# %%
import torch
print(torch.__version__)
# Out:
# 2.10.0+cu128

# %%
import torch
if torch.cuda.is_available():
    print("Gpu is available")
    print(f"using Gpu:{torch.cuda.get_device_name(0)}")
else:
    print("Gpu not available")
# Out:
# /home/saf369/Projects/pytorch/venv/lib/python3.12/site-packages/torch/_subclasses/functional_tensor.py:283: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))
# Gpu not available

# %%
a=torch.empty(2,3)
type(a)
torch.zeros(2,3)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
def dy_dx(x):
    return 2*x
dy_dx(3)
# Out:
# 6

# %%
import math
def dz_dx(x):
    return 2 * x*math.cos(x**2)
dz_dx(2)
# Out:
# -2.6145744834544478

# %%
import torch
x=torch.tensor([1.0,2.0,3.0],requires_grad=True)
y=x*2
y.sum().backward()
print(x.grad)
# Out:
# /home/saf369/Projects/pytorch/venv/lib/python3.12/site-packages/torch/_subclasses/functional_tensor.py:283: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))
# tensor([2., 2., 2.])

# %%
import numpy as np
import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.datasets import load_breast_cancer


df=pd.read_csv("breast-cancer.csv")
df.head()
# df.shape
# Out:
#      age mefalsepause tumor-size  ... breast-quad irradiat                    class
# 0  40-49   premefalse      15-19  ...     left_up    False        recurrence-events
# 1  50-59         ge40      15-19  ...     central    False  false-recurrence-events
# 2  50-59         ge40      35-39  ...    left_low    False        recurrence-events
# 3  40-49   premefalse      35-39  ...    left_low     True  false-recurrence-events
# 4  40-49   premefalse      30-34  ...    right_up    False        recurrence-events
#
# [5 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df.iloc[:, 1:],   # features
    df.iloc[:, 0],    # labels
    test_size=0.2,
    random_state=42
)
